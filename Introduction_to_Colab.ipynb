# %% [markdown]
# <a href="https://colab.research.google.com/github/farah1432/python-practice-problems/blob/main/Introduction_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to **Colab** **bold text**

# %%
import pandas as pd

# %%
pip install pandas

# %%
my_saved_df = pd.read_csv("homelessness.csv")
print(type(df))
my_saved_df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
sorted = my_saved_df.sort_values(
    by= ["region"],
    ascending= [True]
)

sorted.head(50)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 35          35  East North Central                  Ohio       6929.0
# 49          49  East North Central             Wisconsin       2740.0
# 22          22  East North Central              Michigan       5209.0
# 13          13  East North Central              Illinois       6752.0
# 14          14  East North Central               Indiana       3776.0
# 0            0  East South Central               Alabama       2570.0
# 42          42  East South Central             Tennessee       6139.0
# 24          24  East South Central           Mississippi       1024.0
# 17          17  East South Central              Kentucky       2735.0
# 38          38        Mid-Atlantic          Pennsylvania       8163.0
# 32          32        Mid-Atlantic              New York      39827.0
# 30          30        Mid-Atlantic            New Jersey       6048.0
# ...

# %%
individuals	= my_saved_df["individuals"]
print(type(individuals))
print(individuals)
# Out:
# <class 'pandas.core.series.Series'>
# 0       2570.0
# 1       1434.0
# 2       7259.0
# 3       2280.0
# 4     109008.0
# 5       7607.0
# 6       2280.0
# 7        708.0
# 8       3770.0
# 9      21443.0
# 10      6943.0
# 11      4131.0
# 12      1297.0
# 13      6752.0
# 14      3776.0
# 15      1711.0
# 16      1443.0
# 17      2735.0
# 18      2540.0
# 19      1450.0
# 20      4914.0
# 21      6811.0
# 22      5209.0
# 23      3993.0
# 24      1024.0
# 25      3776.0
# 26       983.0
# 27      1745.0
# 28      7058.0
# 29       835.0
# 30      6048.0
# 31      1949.0
# 32     39827.0
# 33      6451.0
# 34       467.0
# 35      6929.0
# 36      2823.0
# 37     11139.0
# 38      8163.0
# 39       747.0
# 40      3082.0
# 41       836.0
# 42      6139.0
# 43     19199.0
# 44      1904.0
# 45       780.0
# 46      3928.0
# 47     16424.0
# 48      1021.0
# 49      2740.0
# 50       434.0
# Name: individuals, dtype: float64

# %%
state	= my_saved_df["state"]
print(type(state))
print(state)
# Out:
# <class 'pandas.core.series.Series'>
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# ...

# %%
mask = my_saved_df["state"]=="Utah"
df_Mountain = df [mask]
print(df_Mountain)
df_Mountain.head(20)
# Out:
#     Unnamed: 0    region state  individuals  family_members  state_pop
# 44          44  Mountain  Utah       1904.0           972.0    3153550
#     Unnamed: 0    region state  individuals  family_members  state_pop
# 44          44  Mountain  Utah       1904.0           972.0    3153550
